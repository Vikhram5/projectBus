# %%
import pandas as pd
import numpy as np
import os 

#input for any file name
file_name=input("Enter File Name: ")
journey=input("Enter 'up' or 'down': ").lower()
file_path=os.path.join('week_data',journey, file_name)

if not os.path.isfile(file_path):
    print(f"Error: File '{file_name}' does not exist.")
else:
    df=pd.read_csv(file_path)
# Out:
# Enter File Name: 04-02-19.csv
# Enter 'up' or 'down': up

# %%
#Only 519 buses
bus_no = int(input("Enter bus Number: "))
df = df[df['Schedule Name'].str.contains(rf'\b{bus_no}\b')]
df
# Out:
# Enter bus Number: 519
#       WayBill No          Depot  Schedule Name    ETM No    Out Date Out Time  \
# 47434     O00301          ADYAR  519-J1-AS-MDE  MP19055I  04-02-2019  42:05.0
# 47435     O00301          ADYAR  519-J1-AS-MDE  MP19055I  04-02-2019  42:05.0
# 47436     O00301          ADYAR  519-J1-AS-MDE  MP19055I  04-02-2019  42:05.0
# 47437     O00301          ADYAR  519-J1-AS-MDE  MP19055I  04-02-2019  42:05.0
# 47438     O00301          ADYAR  519-J1-AS-MDE  MP19055I  04-02-2019  42:05.0
# ...          ...            ...            ...       ...         ...      ...
# 51794     A00081  KANNAGI NAGAR   519-S-AS-MDE  MP17137J  04-02-2019  25:47.0
# 51795     A00081  KANNAGI NAGAR   519-S-AS-MDE  MP17137J  04-02-2019  25:47.0
# 51796     A00081  KANNAGI NAGAR   519-S-AS-MDE  MP17137J  04-02-2019  25:47.0
# 51797     A00081  KANNAGI NAGAR   519-S-AS-MDE  MP17137J  04-02-2019  25:47.0
# 51798     A00081  KANNAGI NAGAR   519-S-AS-MDE  MP17137J  04-02-2019  25:47.0
#
#           In Date  In Time  Total Amount  Adult  ...  Trip No Concession  \
# 47434  04-02-2019  03:51.0            15      1  ...        2          0
# 47435  04-02-2019  03:51.0            15      1  ...        2          0
# 47436  04-02-2019  03:51.0            11      1  ...        2          0
# 47437  04-02-2019  03:51.0            15      1  ...        2          0
# 47438  04-02-2019  03:51.0            15      1  ...        2          0
# ...           ...      ...           ...    ...  ...      ...        ...
# 51794  05-02-2019  16:27.0            92      4  ...       10          0
# 51795  05-02-2019  16:27.0            15      1  ...       10          0
# 51796  05-02-2019  16:27.0            15      1  ...       10          0
# 51797  05-02-2019  16:27.0            13      1  ...       10          0
# 51798  05-02-2019  16:27.0            23      1  ...       10          0
#
#       Conductor ID Driver ID Trip Start Date Trip Start Time  Trip End Date  \
# 47434       C50306    D56019      04-02-2019        00:02:12     04-02-2019
# 47435       C50306    D56019      04-02-2019        00:02:12     04-02-2019
# 47436       C50306    D56019      04-02-2019        00:02:12     04-02-2019
# 47437       C50306    D56019      04-02-2019        00:02:12     04-02-2019
# 47438       C50306    D56019      04-02-2019        00:02:12     04-02-2019
# ...            ...       ...             ...             ...            ...
# 51794       C53054    D56333      04-02-2019        22:22:32     04-02-2019
# 51795       C53054    D56333      04-02-2019        22:22:32     04-02-2019
# 51796       C53054    D56333      04-02-2019        22:22:32     04-02-2019
# 51797       C53054    D56333      04-02-2019        22:22:32     04-02-2019
# 51798       C53054    D56333      04-02-2019        22:22:32     04-02-2019
#
#       Trip End Time    Source  Destination
# 47434      01:03:12  BROADWAY  KELAMBAKKAM
# 47435      01:03:12  BROADWAY  KELAMBAKKAM
# 47436      01:03:12  BROADWAY  KELAMBAKKAM
# 47437      01:03:12  BROADWAY  KELAMBAKKAM
# 47438      01:03:12  BROADWAY  KELAMBAKKAM
# ...             ...       ...          ...
# 51794      23:25:32   T.NAGAR   THIRUPORUR
# 51795      23:25:32   T.NAGAR   THIRUPORUR
# 51796      23:25:32   T.NAGAR   THIRUPORUR
# 51797      23:25:32   T.NAGAR   THIRUPORUR
# 51798      23:25:32   T.NAGAR   THIRUPORUR
#
# [4365 rows x 30 columns]

# %%
source_stage=input("Enter source stage: ")
destination_stage=input("Enter destination stage: ")

df=df[(df['Source']==source_stage) & (df['Destination']==destination_stage)]

df['Trip Start Time'] = pd.to_datetime(df['Trip Start Time'], format='%H:%M:%S')
df['Trip End Time'] = pd.to_datetime(df['Trip End Time'], format='%H:%M:%S')

cols=['Schedule Name','Adult','Trip Start Time','Trip End Time','Source','Destination']
df=df.sort_values(by='Trip Start Time')
df=df[cols]
# Out:
# Enter source stage: T.NAGAR
# Enter destination stage: THIRUPORUR
# /var/folders/2g/gwwm3zn90zl4tt8sy0sfn9zh0000gn/T/ipykernel_95447/3089802099.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Trip Start Time'] = pd.to_datetime(df['Trip Start Time'], format='%H:%M:%S')
# /var/folders/2g/gwwm3zn90zl4tt8sy0sfn9zh0000gn/T/ipykernel_95447/3089802099.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Trip End Time'] = pd.to_datetime(df['Trip End Time'], format='%H:%M:%S')

# %%
df['Duration'] = df['Trip End Time'] - df['Trip Start Time']
df['Trip Start Time'] = df['Trip Start Time'].dt.time
df['Trip End Time'] = df['Trip End Time'].dt.time
df['Duration'] = df['Duration'].apply(lambda x: str(x).split()[-1])
df['Passenger Count'] = df.groupby(['Schedule Name', 'Trip Start Time', 'Trip End Time'])['Adult'].transform('sum')

df=df.drop(columns=['Adult'])

df=df.drop_duplicates()
print(df.to_string(index=False))
# Out:
# Schedule Name Trip Start Time Trip End Time  Source Destination Duration  Passenger Count
# 519-K1-AS-MDE        00:00:00      00:53:00 T.NAGAR  THIRUPORUR 00:53:00               43
# 519-N1-AS-MDE        00:01:48      01:09:48 T.NAGAR  THIRUPORUR 01:08:00               24
# 519-X1-AS-MDE        00:01:50      01:46:50 T.NAGAR  THIRUPORUR 01:45:00               79
# 519-N1-AS-MDE        00:18:00      01:26:00 T.NAGAR  THIRUPORUR 01:08:00               91
# 519-K1-AS-MDE        00:21:00      02:15:00 T.NAGAR  THIRUPORUR 01:54:00               16
# 519-J1-AS-MDE        01:07:08      02:29:08 T.NAGAR  THIRUPORUR 01:22:00               41
#  519-Q-AS-MDE        01:10:00      01:37:00 T.NAGAR  THIRUPORUR 00:27:00               35
# 519-B1-AS-MDE        05:04:00      06:57:00 T.NAGAR  THIRUPORUR 01:53:00                8
# 519-A1-AS-MDE        05:22:10      06:25:10 T.NAGAR  THIRUPORUR 01:03:00               24
#  519-R-AS-MDE        05:37:46      06:26:46 T.NAGAR  THIRUPORUR 00:49:00                9
# 519-C1-AS-MDE        05:46:00      07:07:00 T.NAGAR  THIRUPORUR 01:21:00               12
# 519-D1-AS-MDE        05:59:00      07:23:00 T.NAGAR  THIRUPORUR 01:24:00               22
# 519-E1-AS-MDE        05:59:34      06:48:34 T.NAGAR  THIRUPORUR 00:49:00                9
# 519-H1-AS-MDE        06:03:00      07:34:00 T.NAGAR  THIRUPORUR 01:31:00               23
# 519-F1-AS-MDE        06:05:15      07:05:15 T.NAGAR  THIRUPORUR 01:00:00               24
# 519-G1-AS-MDE        06:06:00      07:57:00 T.NAGAR  THIRUPORUR 01:51:00               33
# 519-I1-AS-MDE        06:31:00      07:51:00 T.NAGAR  THIRUPORUR 01:20:00               32
# 519-M1-AS-MDE        06:35:00      08:22:00 T.NAGAR  THIRUPORUR 01:47:00               36
# 519-O1-AS-MDE        06:43:00      08:35:00 T.NAGAR  THIRUPORUR 01:52:00               26
# 519-T1-AS-MDE        06:44:00      09:04:00 T.NAGAR  THIRUPORUR 02:20:00               72
# 519-L1-AS-MDE        06:59:00      08:54:00 T.NAGAR  THIRUPORUR 01:55:00               54
# 519-V1-AS-MDE        07:12:00      09:08:00 T.NAGAR  THIRUPORUR 01:56:00               73
#  519-R-AS-MDE        07:44:00      09:40:00 T.NAGAR  THIRUPORUR 01:56:00               74
# 519-Z1-AS-MDE        08:05:00      10:23:00 T.NAGAR  THIRUPORUR 02:18:00              122
# 519-A1-AS-MDE        08:30:00      10:46:00 T.NAGAR  THIRUPORUR 02:16:00               78
# 519-B1-AS-MDE        08:41:00      10:58:00 T.NAGAR  THIRUPORUR 02:17:00              128
# 519-E1-AS-MDE        08:56:00      11:15:00 T.NAGAR  THIRUPORUR 02:19:00               96
# 519-C1-AS-MDE        09:06:00      10:57:00 T.NAGAR  THIRUPORUR 01:51:00               91
# 519-X1-AS-MDE        09:09:45      10:59:45 T.NAGAR  THIRUPORUR 01:50:00               97
# 519-D1-AS-MDE        09:17:00      11:26:00 T.NAGAR  THIRUPORUR 02:09:00               93
# 519-F1-AS-MDE        09:32:00      11:23:00 T.NAGAR  THIRUPORUR 01:51:00               97
# 519-H1-AS-MDE        09:57:00      11:44:00 T.NAGAR  THIRUPORUR 01:47:00               64
# 519-I1-AS-MDE        10:12:00      12:00:00 T.NAGAR  THIRUPORUR 01:48:00               49
#  519-S-AS-MDE        10:15:17      11:57:17 T.NAGAR  THIRUPORUR 01:42:00               53
# 519-W1-AS-MDE        10:21:36      11:50:36 T.NAGAR  THIRUPORUR 01:29:00               48
# 519-G1-AS-MDE        10:40:00      12:32:00 T.NAGAR  THIRUPORUR 01:52:00               53
# 519-O1-AS-MDE        10:50:48      12:28:48 T.NAGAR  THIRUPORUR 01:38:00               31
# 519-M1-AS-MDE        10:50:55      12:29:55 T.NAGAR  THIRUPORUR 01:39:00               36
# 519-L1-AS-MDE        11:04:00      13:02:00 T.NAGAR  THIRUPORUR 01:58:00               42
# 519-V1-AS-MDE        11:22:00      13:11:00 T.NAGAR  THIRUPORUR 01:49:00               25
#  519-Q-AS-MDE        11:26:00      13:11:00 T.NAGAR  THIRUPORUR 01:45:00               20
#  519-R-AS-MDE        11:28:00      13:13:00 T.NAGAR  THIRUPORUR 01:45:00               44
# 519-T1-AS-MDE        11:39:58      13:10:58 T.NAGAR  THIRUPORUR 01:31:00               26
# 519-A1-AS-MDE        12:41:00      14:29:00 T.NAGAR  THIRUPORUR 01:48:00               94
# 519-B1-AS-MDE        12:54:20      14:35:20 T.NAGAR  THIRUPORUR 01:41:00               93
# 519-E1-AS-MDE        13:00:00      14:51:00 T.NAGAR  THIRUPORUR 01:51:00               83
# 519-C1-AS-MDE        13:12:00      14:37:00 T.NAGAR  THIRUPORUR 01:25:00               74
# 519-X1-AS-MDE        13:12:34      14:37:34 T.NAGAR  THIRUPORUR 01:25:00               94
# 519-D1-AS-MDE        13:15:00      14:58:00 T.NAGAR  THIRUPORUR 01:43:00               49
# 519-F1-AS-MDE        13:39:16      14:50:16 T.NAGAR  THIRUPORUR 01:11:00               45
# 519-W1-AS-MDE        13:40:00      15:34:00 T.NAGAR  THIRUPORUR 01:54:00               39
# 519-H1-AS-MDE        13:40:00      15:10:00 T.NAGAR  THIRUPORUR 01:30:00               46
# 519-Z1-AS-MDE        13:46:00      15:17:00 T.NAGAR  THIRUPORUR 01:31:00               54
#  519-S-AS-MDE        13:50:00      15:48:00 T.NAGAR  THIRUPORUR 01:58:00               22
# 519-I1-AS-MDE        13:53:00      15:35:00 T.NAGAR  THIRUPORUR 01:42:00               85
# 519-O1-AS-MDE        14:13:00      16:27:00 T.NAGAR  THIRUPORUR 02:14:00               65
# 519-G1-AS-MDE        14:15:00      15:57:00 T.NAGAR  THIRUPORUR 01:42:00               40
# 519-M1-AS-MDE        14:18:00      15:45:00 T.NAGAR  THIRUPORUR 01:27:00               57
#  519-Q-AS-MDE        14:59:00      16:46:00 T.NAGAR  THIRUPORUR 01:47:00               79
# 519-V1-AS-MDE        15:04:00      16:52:00 T.NAGAR  THIRUPORUR 01:48:00               71
# 519-L1-AS-MDE        15:05:40      16:34:40 T.NAGAR  THIRUPORUR 01:29:00               26
# 519-X1-AS-MDE        15:39:09      17:11:09 T.NAGAR  THIRUPORUR 01:32:00               61
# 519-A1-AS-MDE        16:13:51      18:08:51 T.NAGAR  THIRUPORUR 01:55:00               73
# 519-B1-AS-MDE        16:19:38      18:16:38 T.NAGAR  THIRUPORUR 01:57:00               66
# 519-E1-AS-MDE        16:32:00      18:38:00 T.NAGAR  THIRUPORUR 02:06:00               88
# 519-C1-AS-MDE        16:32:00      18:08:00 T.NAGAR  THIRUPORUR 01:36:00               33
# 519-F1-AS-MDE        16:38:00      18:37:00 T.NAGAR  THIRUPORUR 01:59:00               92
# 519-X1-AS-MDE        16:39:35      18:11:35 T.NAGAR  THIRUPORUR 01:32:00               48
# 519-D1-AS-MDE        16:44:00      18:45:00 T.NAGAR  THIRUPORUR 02:01:00               70
# 519-H1-AS-MDE        17:01:00      18:59:00 T.NAGAR  THIRUPORUR 01:58:00               83
# 519-Z1-AS-MDE        17:22:00      19:13:00 T.NAGAR  THIRUPORUR 01:51:00               92
# 519-I1-AS-MDE        17:27:00      19:12:00 T.NAGAR  THIRUPORUR 01:45:00               99
# 519-W1-AS-MDE        17:35:00      19:33:00 T.NAGAR  THIRUPORUR 01:58:00               64
#  519-S-AS-MDE        17:51:00      20:39:00 T.NAGAR  THIRUPORUR 02:48:00               97
# 519-M1-AS-MDE        18:06:58      18:49:58 T.NAGAR  THIRUPORUR 00:43:00               12
# 519-O1-AS-MDE        18:10:35      20:13:35 T.NAGAR  THIRUPORUR 02:03:00               90
# 519-L1-AS-MDE        18:50:00      21:06:00 T.NAGAR  THIRUPORUR 02:16:00              101
#  519-R-AS-MDE        18:53:00      20:59:00 T.NAGAR  THIRUPORUR 02:06:00               73
#  519-Q-AS-MDE        18:59:00      21:03:00 T.NAGAR  THIRUPORUR 02:04:00               77
# 519-T1-AS-MDE        19:01:47      21:05:47 T.NAGAR  THIRUPORUR 02:04:00               94
# 519-V1-AS-MDE        19:19:00      21:13:00 T.NAGAR  THIRUPORUR 01:54:00               72
# 519-X1-AS-MDE        19:25:56      21:26:56 T.NAGAR  THIRUPORUR 02:01:00               62
# 519-C1-AS-MDE        20:33:56      21:01:56 T.NAGAR  THIRUPORUR 00:28:00                5
# 519-W1-AS-MDE        21:27:02      22:47:02 T.NAGAR  THIRUPORUR 01:20:00               72
#  519-S-AS-MDE        22:22:32      23:25:32 T.NAGAR  THIRUPORUR 01:03:00               60

# %%
store_file=input("Enter store file ")
df.to_excel(store_file)
